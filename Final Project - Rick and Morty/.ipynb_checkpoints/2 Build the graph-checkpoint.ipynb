# %% [markdown]
# #### Final Project: Rick & Morty analysis
#
# # Phase 2: Build the graph

# %%
# imports
import pandas as pd
import ast
import networkx as nx
import matplotlib.pyplot as plt

def make_clickable(val):
    return '<a target="_blank" href="{}">{}</a>'.format(val, val)

# %% [markdown]
# ## Download previous files

# %%
df_characters = pd.read_csv("RaM_characters_wRelations.csv")

# %%
def add_node(row, aGraph):
    """ Add the node given in row to global network """
    aGraph.add_node(row.Name)

def add_edges(row, aGraph):
    """ Add all edges which concern given character in row"""
    char_name = row.Name
    char_relations = ast.literal_eval(row.Relations)
    for aTargetRelation in char_relations:
        aGraph.add_edge(char_name,aTargetRelation)

# %%
# Create the associate graph with all attributes : role, race, genre, contentLength
G = nx.DiGraph()
_ = df_characters.apply(add_node, args=(G,), axis=1)
_ = df_characters.apply(add_edges, args=(G,), axis=1)

# Extract the Giant Connected Component, GCC
GCC = nx.weakly_connected_components(G)
GCC = list(GCC)
GCC.sort(key=len)
concerned_nodes = GCC[-1]

GCC = G.subgraph(concerned_nodes).copy()

# make G undirected
GU = G.to_undirected()

# %%
G.number_of_nodes()
# Out:
# 547

# %%
G.number_of_edges()
# Out:
# 2010

# %%
# store in and out degree
df_characters['in_degree'] = df_characters['Name'].map(dict(G.in_degree))
df_characters['out_degree'] = df_characters['Name'].map(dict(G.out_degree))

# %%
plt.hist(df_characters['in_degree'])
# Out:
# (array([541.,   1.,   2.,   1.,   0.,   0.,   0.,   0.,   1.,   1.]),
#  array([  0. ,  27.2,  54.4,  81.6, 108.8, 136. , 163.2, 190.4, 217.6,
#         244.8, 272. ]),
#  <BarContainer object of 10 artists>)

# %%
df_characters['in_degree'].describe()
# Out:
# count    547.000000
# mean       3.674589
# std       16.684098
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        3.000000
# max      272.000000
# Name: in_degree, dtype: float64

# %%
plt.hist(df_characters['out_degree'])
# Out:
# (array([335., 165.,  26.,  13.,   2.,   1.,   2.,   1.,   0.,   2.]),
#  array([ 0.,  4.,  8., 12., 16., 20., 24., 28., 32., 36., 40.]),
#  <BarContainer object of 10 artists>)

# %%
df_characters['out_degree'].describe()
# Out:
# count    547.000000
# mean       3.674589
# std        4.031487
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        5.000000
# max       40.000000
# Name: out_degree, dtype: float64

# %%
df_characters.sort_values('in_degree',ascending=False)[['Name','out_degree','in_degree']].head(10)
# Out:
#                  Name  out_degree  in_degree
# 387      Rick Sanchez          40        272
# 304       Morty Smith          36        240
# 546       Jerry Smith          26         85
# 466      Summer Smith          30         73
# 42         Beth Smith          25         64
# 140        Evil Morty           8         29
# 87   Council of Ricks          14         27
# 479    Tammy Guterman          11         26
# 53         Birdperson           8         24
# 192      Gromflomites           7         23

# %%
df_characters.sort_values('out_degree',ascending=False)[['Name','out_degree','in_degree']].head(10)
# Out:
#                                       Name  out_degree  in_degree
# 387                           Rick Sanchez          40        272
# 304                            Morty Smith          36        240
# 466                           Summer Smith          30         73
# 546                            Jerry Smith          26         85
# 42                              Beth Smith          25         64
# 291                       Memory Parasites          20         16
# 469  Summer Smith (Cronenberged dimension)          19         10
# 204                             Hemorrhage          18         16
# 232   Jerry Smith (Cronenberged dimension)          15         16
# 302                              Morty Jr.          15         18

# %% [markdown]
# ## Generate CSV for GePhi

# %%
df_characters = pd.read_csv('df_characters_with_attributes.csv').drop('Unnamed: 0', axis=1)
df_characters
# Out:
#                    Name                                          Hyperlink  \
# 0      Abandoned Jerrys  https://rickandmorty.fandom.com/wiki/Abandoned...
# 1    Abrodolph Lincoler  https://rickandmorty.fandom.com/wiki/Abrodolph...
# 2                  Adam          https://rickandmorty.fandom.com/wiki/Adam
# 3      Adjudicator Rick  https://rickandmorty.fandom.com/wiki/Adjudicat...
# 4             Afro Rick     https://rickandmorty.fandom.com/wiki/Afro_Rick
# ..                  ...                                                ...
# 535       Zeep Xanflorp  https://rickandmorty.fandom.com/wiki/Zeep_Xanf...
# 536          Zerillians    https://rickandmorty.fandom.com/wiki/Zerillians
# 537     Zeta Alpha Rick  https://rickandmorty.fandom.com/wiki/Zeta_Alph...
# 538         Jerry Smith   https://rickandmorty.fandom.com/wiki/Jerry_Smith
# 539         Morty Smith   https://rickandmorty.fandom.com/wiki/Morty_Smith
#
#                                              Relations   Species  \
# ...

# %% [markdown]
# ## Get GePhi nodes csv

# %% [markdown]
# Simple list of nodes with name only

# %%
df_characters = pd.read_csv('RaM_characters.csv')
df_gephi_nodes = df_characters[['Name']].copy()
df_gephi_nodes = df_gephi_nodes.rename(columns={'Name':'Id'})
df_gephi_nodes['Label'] = df_gephi_nodes.Id
#df_gephi_nodes.to_csv('RaM_gephi_nodes_simple.csv', index=False)
df_gephi_nodes.head()
# Out:
#                    Id               Label
# 0    Abandoned Jerrys    Abandoned Jerrys
# 1  Abrodolph Lincoler  Abrodolph Lincoler
# 2                Adam                Adam
# 3    Adjudicator Rick    Adjudicator Rick
# 4           Afro Rick           Afro Rick

# %% [markdown]
# Add timestamp to creation animated network

# %%
import time
from datetime import datetime, timedelta

# %%
# Converting datetime object to string
dateTimeObj = datetime.now()
timestampStr = dateTimeObj.strftime("%d-%b-%Y (%H:%M:%S.%f)")
print('Current Timestamp : ', dateTimeObj)
# Out:
# Current Timestamp :  2021-12-01 15:05:40.902655

# %%
# add timestamp to nodes
df_gephi_nodes['start']=[(dateTimeObj-timedelta(days=i+3)).strftime("%d/%m/%y") for i in range (len(df_characters))]
df_gephi_nodes['end']=[(dateTimeObj).strftime("%d/%m/%y") for i in range (len(df_characters))]
# df_gephi_nodes['Timestamp']=[i+1 for i in range (len(df_characters))]

# %%
df_gephi_nodes.head()
# Out:
#                    Id               Label  Timestamp     start       end
# 0    Abandoned Jerrys    Abandoned Jerrys          1  28/11/21  01/12/21
# 1  Abrodolph Lincoler  Abrodolph Lincoler          2  27/11/21  01/12/21
# 2                Adam                Adam          3  26/11/21  01/12/21
# 3    Adjudicator Rick    Adjudicator Rick          4  25/11/21  01/12/21
# 4           Afro Rick           Afro Rick          5  24/11/21  01/12/21

# %%
df_gephi_nodes.to_csv('RaM_gephi_nodes_simple.csv', index=False)

# %% [markdown]
# Add attributes

# %%
df_gephi_nodes = df_characters[['Name', 'Species', 'Gender','Origin','Status']].copy()
df_gephi_nodes = df_gephi_nodes.rename(columns={'Name':'Id'})
df_gephi_nodes['Label'] = df_gephi_nodes.Id

# Save as a csv
# df_gephi_nodes.to_csv('RaM_gephi_nodes.csv', index=False)

df_gephi_nodes.head()
# Out:
#                    Id   Species      Gender            Origin   Status  \
# 0    Abandoned Jerrys   unknown  Genderless           unknown  unknown
# 1  Abrodolph Lincoler   unknown  Genderless           unknown  unknown
# 2                Adam  Humanoid        Male  Narnia Dimension     Dead
# 3    Adjudicator Rick     Human        Male           unknown     Dead
# 4           Afro Rick   unknown  Genderless           unknown  unknown
#
#                 Label
# 0    Abandoned Jerrys
# 1  Abrodolph Lincoler
# 2                Adam
# 3    Adjudicator Rick
# 4           Afro Rick

# %%
df_characters2 = pd.read_csv('df_characters_with_attr_and_communities.csv')
df_characters2.head()

# %%
df_characters[df_characters.Name=='Evil Morty']
# Out:
# Empty DataFrame
# Columns: [Name, Hyperlink, Relations, Species, Origin, Gender, Status]
# Index: []

# %%
df_gephi_nodes2 = df_characters2[['Name', 'Species', 'Gender','Origin','Status','community']].copy()
df_gephi_nodes2 = df_gephi_nodes2.rename(columns={'Name':'Id'})
df_gephi_nodes2['Label'] = df_gephi_nodes2.Id

# Save as a csv
# df_gephi_nodes2.to_csv('RaM_gephi_nodes2.csv', index=False)

df_gephi_nodes2.head()
# Out:
#                    Id   Species      Gender            Origin   Status  \
# 0    Abandoned Jerrys   unknown  Genderless           unknown  unknown
# 1  Abrodolph Lincoler   unknown  Genderless           unknown  unknown
# 2                Adam  Humanoid        Male  Narnia Dimension     Dead
# 3    Adjudicator Rick     Human        Male           unknown     Dead
# 4           Afro Rick   unknown  Genderless           unknown  unknown
#
#    community               Label
# 0        0.0    Abandoned Jerrys
# 1        1.0  Abrodolph Lincoler
# 2        NaN                Adam
# 3        2.0    Adjudicator Rick
# 4        2.0           Afro Rick

# %% [markdown]
# ## Get GePhi links csv

# %%
# classical links table based on relations
df_characters = pd.read_csv('RaM_characters_wRelations.csv')
df_gephi_links = pd.DataFrame(columns=['Source','Target'])

for index, row in df_characters.iterrows():
    relations = ast.literal_eval(row.Relations)
    for aTarget in relations:
        df_gephi_links = df_gephi_links.append({'Source':row.Name, 'Target':aTarget}, ignore_index=True)

# Save as a csv
# df_gephi_links.to_csv('RaM_gephi_edges.csv', index=False)

df_gephi_links.head()
# Out:
#                Source        Target
# 0    Abandoned Jerrys   Jerry Smith
# 1  Abrodolph Lincoler  Rick Sanchez
# 2  Abrodolph Lincoler          Brad
# 3  Abrodolph Lincoler   Morty Smith
# 4  Abrodolph Lincoler         Nancy

# %%
# add a timestamp ?

# %% [markdown]
# ---

# %%
list(df_characters[df_characters.Name=='Rick Sanchez'].Relations)
# Out:
# ['[\'Mr. Nimbus\', \'Big Fat Rick\', \'Evil Morty\', \'Beth Sanchez (C-137)\', \'Jerry Smith (Cronenberged dimension)\', \'Summer Smith (Cronenberged dimension)\', \'Morty Smith\', \'Beth Smith\', \'Summer Smith\', \'Jerry Smith\', \'Morty Jr.\', \'Naruto Smith\', \'Diane Sanchez\', \'Poñeta\', "Rick\'s Foal", \'Unity\', \'Gaia\', \'Balthromaw\', \'Weird Rick\', \'Birdperson\', \'Squanchy\', \'Fart\', \'Mr. Poopybutthole\', \'Tammy Guterman\', \'Arthricia\', \'Mr. Goldenfold\', \'Evil Rick Sanchez\', \'Council of Ricks\', \'Shleemypants\', \'Krombopulos Michael\', \'Gromflomites\', \'SEAL Team Ricks\', \'Blim Blam\', \'Jessica\', \'Lucius Needful\', \'Snuffles\', \'Kiara\', \'Trandor\', \'Wasp Rick\', \'Doofus Rick\']']

# %%
df_characters2['degree']=df_characters2['in_degree']+df_characters2['out_degree']

# %% [markdown]
# Rick Sanchez, Evil Rick Sanchez, Toxic Rick
#
#
#
# Rick's Foal, Maximums Rickimus, Ricktiminus Sancheziminius, Rick Sanchez (Evil Rick's Target Dimension), Zeta Alpha Rick, Rick Sanchez (Replacement Dimension), The Scientist Formerly Known as Rick, Tiny Rick,

# %%
df_find_Ricks = df_characters2[df_characters2.Name.str.contains('Rick')].sort_values('degree',ascending=False)[['Name', 'Hyperlink','degree']]
df_find_Ricks.style.format(make_clickable, 'Hyperlink')
# Out:
# <style type="text/css">
# </style>
# <table id="T_83991_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Name</th>
#       <th class="col_heading level0 col1" >Hyperlink</th>
#       <th class="col_heading level0 col2" >degree</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83991_level0_row0" class="row_heading level0 row0" >380</th>
#       <td id="T_83991_row0_col0" class="data row0 col0" >Rick Sanchez</td>
#       <td id="T_83991_row0_col1" class="data row0 col1" ><a target="_blank" href="https://rickandmorty.fandom.com/wiki/Rick_Sanchez">https://rickandmorty.fandom.com/wiki/Rick_Sanchez</a></td>
#       <td id="T_83991_row0_col2" class="data row0 col2" >307</td>
#     </tr>
#     <tr>
#       <th id="T_83991_level0_row1" class="row_heading level0 row1" >85</th>
#       <td id="T_83991_row1_col0" class="data row1 col0" >Council of Ricks</td>
# ...

# %%
df_characters2[df_characters2.Name.str.contains('Morty')].sort_values('degree',ascending=False).head(20)
# Out:
#                                            Name  \
# 539                                 Morty Smith
# 296                                   Morty Jr.
# 302         Morty Smith (Replacement Dimension)
# 299                         Morty Smith (C-132)
# 300  Morty Smith (Evil Rick's Target Dimension)
# 298                         Morty Smith (304-X)
# 496                                 Toxic Morty
# 266                                Lizard Morty
# 501                                 Trunk Morty
# 173                               Glasses Morty
# 436                                 Slick Morty
# 91                             Cronenberg Morty
# 523                               Western Morty
# 143                               Fascist Morty
# 58                             Blue Shirt Morty
# 283                            Mechanical Morty
# 17                                Antenna Morty
# 304                             Mortytown Locos
# ...

# %%
df_characters2[df_characters2.Name=='Toxic Rick']
# Out:
#            Name                                        Hyperlink  \
# 497  Toxic Rick  https://rickandmorty.fandom.com/wiki/Toxic_Rick
#
#                                              Relations   Species      Origin  \
# 497  ['Toxic Morty', 'Rick Sanchez', 'Healthy Rick'...  Humanoid  Detoxifier
#
#     Gender Status  in_degree  out_degree  community  degree
# 497   Male   Dead          3           6        4.0       9

# %%
df_characters0 = pd.read_csv('RaM_characters.csv')

# %%
df_characters0[df_characters0.Name=='Evil Morty']
# Out:
#            Name                                        Hyperlink
# 140  Evil Morty  https://rickandmorty.fandom.com/wiki/Evil_Morty

# %%
df_characters_with_relations_only = pd.read_csv('RaM_characters_wRelations.csv')
df_characters_with_relations_only[df_characters_with_relations_only.Name=='Memory Rick'].Relations.values
# Out:
# array(["['Birdperson', 'Rick Sanchez (Replacement Dimension)', 'Tammy Guterman', 'Morty Smith']"],
#       dtype=object)

# %%
df_characters_current = pd.read_csv('df_characters_with_attributes.csv')
df_characters_current[df_characters_current.Name=='Evil Morty']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Hyperlink, Relations, Species, Origin, Gender, Status]
# Index: []
