# %% [markdown]
# # Studying Centrality Measures

# %%
import pandas as pd
import numpy as np

# %%
nodes = pd.read_csv('GePhi_nodes_export.csv')
nodes.head()
# Out:
#                    Id               Label  timeset   species  \
# 0    Abandoned Jerrys    Abandoned Jerrys      NaN     Human
# 1  Abrodolph Lincoler  Abrodolph Lincoler      NaN     Human
# 2                Adam                Adam      NaN  Humanoid
# 3    Adjudicator Rick    Adjudicator Rick      NaN     Human
# 4           Afro Rick           Afro Rick      NaN     Human
#
#                    origin gender   status  indegree  outdegree  degree  ...  \
# 0                   Earth   Male    Alive         0          1       1  ...
# 1                 unknown   Male  unknown         5          4       9  ...
# 2        Narnia Dimension   Male     Dead         0          0       0  ...
# 3                 unknown   Male     Dead         1          1       2  ...
# 4  Earth (Dimension E-33)   Male    Alive         2          7       9  ...
#
#    harmonicclosnesscentrality  betweenesscentrality  Authority       Hub  \
# ...
