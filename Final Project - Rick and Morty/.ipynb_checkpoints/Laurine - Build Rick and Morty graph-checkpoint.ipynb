# %%
# IMPORT
import urllib.request
import json
import re
import html_to_json

# %%
# !pip install html-to-json
# Out:
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=0886900368ae76813899f7ab6619dbd40ff6c117dad724824ca02956da3908db
#   Stored in directory: c:\users\laurine\appdata\local\pip\cache\wheels\75\78\21\68b124549c9bdc94f822c02fb9aa3578a669843f9767776bca
# Successfully built bs4
# ...

# %%
# Get the list of characters
baseurl = "https://rickandmorty.fandom.com/wiki/Category:Characters"
wikiresponse = urllib.request.urlopen(baseurl)
wikidata = wikiresponse.read()
wikitext = wikidata.decode('utf-8')

# %% [markdown]
# `<a href="/wiki/Birdperson%27s_Daughter" class="category-page__member-link" title="Birdperson&#039;s Daughter">Birdperson&#039;s Daughter</a>`

# %%
pattern = '<a href="(?:.*?)" class="category-page__member-link" title="(?:.*?)">(.*?)</a>' 
match = re.findall(pattern,category_page_members)
match
# Out:
# ['Abandoned Jerrys',
#  'Abrodolph Lincoler',
#  'Adam',
#  'Adjudicator Rick',
#  'Afro Rick',
#  'Agent Gribbles',
#  'Alan Rails',
#  'Albert Einstein',
#  'Alexander',
#  'Alien Googah',
#  'Alien Morty',
#  'Alien Rick',
#  'Category:Alternate Versions of Characters',
#  'Alyson Hannigan',
#  'Amfiddians',
#  'Amish Cyborg',
#  'Category:Animals',
#  'Annie',
#  'Annika',
#  'Category:Antagonists',
#  'Antenna Morty',
#  'Antenna Rick',
#  'Ants in my Eyes Johnson',
#  'Ants in my Eyes Morty',
#  'Aqua Morty',
#  'Aqua Rick',
#  'Arcade Alien',
#  'Arm Head Mutant Morty',
#  'Armagheadon',
#  'Armothy',
#  'Arthricia',
#  'Artist Morty',
#  'Attila Starwar',
#  'Baby Legs',
#  'Baby Poopybutthole',
#  'Baby Wizard',
#  'Balthromaw',
#  'Bearded Lady',
#  'Beebo',
#  'Benjamin',
#  'Bepisians',
#  'Beta-Seven',
#  'Beth Sanchez (C-137)',
#  'Beth Sanchez (C-500A)',
#  'Beth Sanchez (Simple Rick&#039;s Dimension)',
#  'Beth Smith',
#  'Beth Smith (304-X)',
# ...

# %%
dictionary_to_read = html_to_json.convert(wikitext)

# %%
category_page_members = dictionary_to_read['html'][0]['body'][0]['div'][3]['div'][2]['div'][1]['main'][0]['div'][2]['div'][0]['div'][2]

# %%
category_page_members
# Out:
# {'_attributes': {'class': ['category-page__members']},
#  'div': [{'_attributes': {'class': ['category-page__members-wrapper']},
#    'div': [{'_attributes': {'class': ['category-page__first-char']},
#      '_value': 'A'}],
#    'ul': [{'_attributes': {'class': ['category-page__members-for-char']},
#      'li': [{'_attributes': {'class': ['category-page__member']},
#        'div': [{'_attributes': {'class': ['category-page__member-left']},
#          'a': [{'_attributes': {'href': '/wiki/Abandoned_Jerrys',
#             'title': 'Abandoned Jerrys'},
#            'img': [{'_attributes': {'src': 'https://static.wikia.nocookie.net/rickandmorty/images/3/3e/S2e2_abandoned_jerrys_room.png/revision/latest/smart/width/40/height/30?cb=20160919225938',
#               'data-src': 'https://static.wikia.nocookie.net/rickandmorty/images/3/3e/S2e2_abandoned_jerrys_room.png/revision/latest/smart/width/40/height/30?cb=20160919225938',
#               'alt': 'Abandoned Jerrys',
# ...
